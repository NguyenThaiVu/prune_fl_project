# %% [markdown]
# # Description
#
# In this notebook, I will train the Federated Learning system with **ResNet architecture.**

# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"]="-1"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
tf.random.set_seed(42)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:  tf.config.experimental.set_memory_growth(gpus[0], True)
  except RuntimeError as e: print(e)

import gc
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skimage.transform import resize

from sklearn.model_selection import train_test_split

from config_celeb import *
from utils.read_data_utils import *
from utils.model_utils import *
from utils.pruning_utils import *
# Out:
# 2024-06-07 16:32:58.436998: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 16:32:58.437015: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 16:32:58.437151: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import os

# =========================================================
# Dataset Hyper-parameter
DATASET_NAME = 'celeb'  # mnist or celeb

IMAGE_DIMENSION = 84
INPUT_SHAPE = (IMAGE_DIMENSION, IMAGE_DIMENSION, 3)
OUPUT_SHAPE = 2
LABEL_NAME = {0: 'female', 1: 'male'}    # Gender classification 


# =========================================================
# Model Hyper-parameter
OPTIMIZER = 'adam'
LOSS = 'categorical_crossentropy'
METRICS = ['accuracy']

LIST_NUMBER_FILTERS = [16, 32, 64]
KERNEL_SIZE = 5
DROPOUT_RATE = 0.1
PATH_GLOBAL_MODEL = os.path.join("models", "global_model_resnet_celeb_prune.h5")


# =========================================================
# Training Hyper-parameter
NUM_ROUNDS = 500
NUM_SELECTED_CLIENT = 50

LOCAL_EPOCHS = 5
LOCAL_BATCH_SIZE = 32

IS_STILL_PRUNE = True
MAX_PRUNED_ROUND = 50
PRUNE_PATIENCE = 0
MAX_PRUNE_PATIENCE = 3

STD_THRESHOLD_PRUNE = 2.0

# %% [markdown]
# # 1. Dataset

# %% [markdown]
# ## 1.1. Load dataset

# %%
celeb_train, celeb_test = tff.simulation.datasets.celeba.load_data()

num_clients = len(celeb_train.client_ids)
print(f"Number of clients: {num_clients}")
# Out:
# Number of clients: 8408

# %% [markdown]
# ## 1.2. Prepare training dataset

# %%
list_clients_data = Create_Clients_Data(celeb_train, DATASET_NAME)
print(f"Number of client: {len(list_clients_data)}")
# Out:
# Number of client: 8408

# %%
idx_client = np.random.randint(0, 10)
idx_sample = np.random.randint(0, 10)

client_data = list_clients_data[idx_client]

client_name = client_data['client_name']
list_X = client_data['list_X']
list_y = client_data['list_y']

X = list_X[idx_sample]
print(f"Shape of image: {X.shape}")
print(f"Max value of X: {X.max()}")
print(f"Min value of X: {X.min()}")

y = list_y[idx_sample]

print(f"Client = {client_name}")
print(f"Label = {y}")
plt.imshow(X, cmap='gray')
plt.show()
# Out:
# Shape of image: (84, 84, 3)
# Max value of X: 255
# Min value of X: 0
# Client = 10001
# Label = [1. 0.]

# %% [markdown]
# ## 1.3. Prepare val - test dataset

# %%
list_data_test = Create_Clients_Data(celeb_test, dataset_name=DATASET_NAME)

X_test = []
y_test = []
for data_test in list_data_test:
    X_test.append(data_test['list_X'])
    y_test.append(data_test['list_y'])
X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=42)
X_val = np.array([resize(image, (IMAGE_DIMENSION, IMAGE_DIMENSION)) for image in X_val])
X_test = np.array([resize(image, (IMAGE_DIMENSION, IMAGE_DIMENSION)) for image in X_test])

# %%
print(f"Shape of X val: {X_val.shape}")
print(f"Shape of y val: {y_val.shape}")
print(f"Max value of X_val: {X_val[3].max()}")
print(f"Min value of X_val: {X_val[3].min()}")
print()
print(f"Shape of X test: {X_test.shape}")
print(f"Shape of y test: {y_test.shape}")
# Out:
# Shape of X val: (9929, 84, 84, 3)
# Shape of y val: (9929, 2)
# Max value of X_val: 1.0
# Min value of X_val: 0.0
#
# Shape of X test: (9930, 84, 84, 3)
# Shape of y test: (9930, 2)

# %% [markdown]
# # 2. FL Training
#
# ## 2.1. Define components

# %%
def Define_ResNet_Model(input_shape, output_shape, list_number_filters, max_pooling_step=2, model_name=None):
    """
    This function create the simple Residual Network model. 
    """
    inputs = layers.Input(shape=input_shape)
    
    # Initial Convolutional Layer
    x = layers.Conv2D(list_number_filters[0], kernel_size=3, strides=2, padding='same', name=f'prunable_conv_0')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(pool_size=max_pooling_step, strides=max_pooling_step, padding='same')(x)
    
    # Residual Blocks
    for (idx_residual_block, number_filters) in enumerate(list_number_filters[1:]):
        x = residual_block(x, num_filters_1=number_filters, num_filters_2=number_filters, strides=(2, 2), idx_residual_block=idx_residual_block)
    
    # Final Layers
    # x = layers.GlobalAveragePooling2D()(x)
    x = Flatten()(x)
    x = layers.Dense(output_shape, activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=x)
    return model

# %%
keras.backend.clear_session()
global_model = Define_ResNet_Model(INPUT_SHAPE, OUPUT_SHAPE, LIST_NUMBER_FILTERS, max_pooling_step=2, model_name=None)
global_model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics = METRICS)
print(f"Number of params: {global_model.count_params()}")

num_conv_layers = Count_Conv2d_Layers(global_model)
print(f"Number of Conv2D layer: {num_conv_layers}")

flops = get_flops_keras_model(global_model)
print(f"FLOPS of global model: {flops}")

plot_model(global_model, to_file=os.path.join('images', f'ResNet-{num_conv_layers}.png'), show_shapes=True, show_layer_names=True);
global_model.save(PATH_GLOBAL_MODEL)
# Out:
# Number of params: 30626
# Number of Conv2D layer: 7
# WARNING:tensorflow:From /home/necphy/miniconda3/envs/fl_env/lib/python3.9/site-packages/tensorflow/python/ops/nn_ops.py:5253: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# WARNING:tensorflow:From /home/necphy/miniconda3/envs/fl_env/lib/python3.9/site-packages/tensorflow/python/ops/nn_ops.py:5253: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# FLOPS of global model: 5234332
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   5.16m float_ops (100.00%, 98.62%)
# BiasAdd                  39.43k float_ops (1.38%, 0.75%)
# MaxPool                  28.22k float_ops (0.63%, 0.54%)
# AddV2                    2.51k float_ops (0.09%, 0.05%)
# MatMul                   2.30k float_ops (0.04%, 0.04%)
# Softmax                     10 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
# /home/necphy/miniconda3/envs/fl_env/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## 2.2. FL training

# %%
def prune_model(model, optimizer, loss_func, metrics, std_threshold=3.0):
    """
    This function take input as model and perform model pruning to return the pruned filters CNN model.

    * Parameters:
        model (keras model): input model.
        optimizer (keras optimizer).
        loss_func (keras loss function).
        metrics (keras metrics)
        std_threshold (integer): threshold to prune filters.

    * Return:
        model (keras model) -- the pruned filters model.
    """

    global IS_STILL_PRUNE
    global PRUNE_PATIENCE
    before_prune_params = model.count_params()

    list_number_filters = []
    for layer in model.layers:
        if isinstance(layer, Conv2D) and layer.name != 'classifier' and 'prunable_conv' in layer.name:
            weights = layer.get_weights()[0]
            pruned_filter = Apply_Pruning_Filter(weights, std_threshold)
            pruned_number_filter = pruned_filter.shape[-1]

            if pruned_number_filter <= 0:
                pruned_number_filter = 1
            list_number_filters.append(pruned_number_filter)

    new_model = Define_ResNet_Model(input_shape=model.input_shape[1:], output_shape=model.output_shape[1], list_number_filters=list_number_filters)
    new_model_params = new_model.count_params()
    print(f"list_number_filters: {list_number_filters}")
    print(f"before_prune_params: {before_prune_params}")
    print(f"new_model_params: {new_model_params}")

    if before_prune_params > new_model_params:
        PRUNE_PATIENCE = 0
        print(f"--- [INFO] This round PRUNE filter ---")
        new_model.compile(optimizer=optimizer, loss=loss_func, metrics=metrics)
        return new_model
    else:
        PRUNE_PATIENCE += 1
        print(f"--- [INFO] This round NOT prune filter ---")
        if PRUNE_PATIENCE >= MAX_PRUNE_PATIENCE:
            IS_STILL_PRUNE = False
            print(f"===== [INFO] Stop prune here! =====")
            print(f"Final params: {before_prune_params}")
        return model

# %%
NUM_CLIENTS = num_clients
list_val_acc = []
list_val_loss = []
list_model_params = []


for idx_round in range(NUM_ROUNDS):
    print("\n [INFO] Round {}".format(idx_round))

    # Load global model at begin of each round.
    global_model = keras.models.load_model(PATH_GLOBAL_MODEL)
    global_model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics = METRICS)
    
    # Perform the pruning process
    if IS_STILL_PRUNE == True:
        if idx_round > MAX_PRUNED_ROUND:
            IS_STILL_PRUNE = False
            print(f"===== [INFO] Stop prune here. Final params: {global_model.count_params()}")
        elif idx_round > 0:
            global_model = prune_model(global_model, optimizer=OPTIMIZER, loss_func=LOSS, metrics=METRICS, std_threshold=STD_THRESHOLD_PRUNE)
    
    # Clients clone model from server
    client_model = keras.models.clone_model(global_model)    
    client_model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics=METRICS)

    selected_clients_data = random.sample(list_clients_data, NUM_SELECTED_CLIENT)  # Random subset clients

    # Loop through selected client
    list_client_model_weight = []
    list_client_scales = []
    for selectd_client_data in selected_clients_data:      

        # Clone client's weight from global model
        client_model.set_weights(global_model.get_weights())

        client_name = selectd_client_data['client_name']
        list_X = selectd_client_data['list_X']
        list_y = selectd_client_data['list_y']
        list_X = list_X.astype(np.float32) / 255.0
        # list_X = np.array([resize(image, (IMAGE_DIMENSION, IMAGE_DIMENSION)) for image in list_X])  # Resize input image shape

        client_model.fit(list_X, list_y, epochs=LOCAL_EPOCHS, batch_size=LOCAL_BATCH_SIZE, verbose=0)

        list_client_model_weight.append(client_model.get_weights())    # store local weight for update global model later.
        list_client_scales.append(len(list_X))
        list_X = list_y = None
        gc.collect()

    
    # Calculate scale of each client
    list_client_scales = np.array(list_client_scales)
    list_client_scales = list_client_scales / list_client_scales.sum()

    # Update the global model weights
    avg_weights = FedAvg(global_model, list_client_model_weight, list_client_scales)
    global_model.set_weights(avg_weights)

    # Evaluate model on validation data
    if idx_round % 20 == 0:
        val_loss, val_acc = global_model.evaluate(X_val, y_val, verbose=0)
        print(f'Val loss: {val_loss}, Val accuracy: {val_acc}')
        list_val_acc.append(val_acc)
        list_val_loss.append(val_loss)

    global_model.save(PATH_GLOBAL_MODEL)
    tf.keras.backend.clear_session()

    selected_clients_data = None
    list_client_model_weight = list_client_scales = None
    gc.collect()
# Out:
#  [INFO] Round 0
# Val loss: 0.7022050023078918, Val accuracy: 0.4311612546443939
#
#  [INFO] Round 1
# list_number_filters: [16, 31, 61]
# before_prune_params: 30626
# new_model_params: 29454
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 2
# list_number_filters: [16, 29, 57]
# before_prune_params: 29454
# new_model_params: 27696
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 3
# list_number_filters: [16, 28, 55]
# before_prune_params: 27696
# new_model_params: 26817
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 4
# list_number_filters: [16, 27, 53]
# before_prune_params: 26817
# new_model_params: 25938
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 5
# list_number_filters: [15, 27, 51]
# before_prune_params: 25938
# new_model_params: 23762
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 6
# list_number_filters: [14, 25, 49]
# before_prune_params: 23762
# new_model_params: 21148
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 7
# list_number_filters: [14, 23, 47]
# before_prune_params: 21148
# new_model_params: 20120
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 8
# list_number_filters: [13, 23, 45]
# before_prune_params: 20120
# new_model_params: 18204
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 9
# list_number_filters: [13, 23, 43]
# before_prune_params: 18204
# new_model_params: 17726
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 10
# list_number_filters: [13, 23, 42]
# before_prune_params: 17726
# new_model_params: 17487
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 11
# list_number_filters: [13, 22, 41]
# before_prune_params: 17487
# new_model_params: 17009
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 12
# list_number_filters: [12, 20, 39]
# before_prune_params: 17009
# new_model_params: 14817
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 13
# list_number_filters: [12, 20, 37]
# before_prune_params: 14817
# new_model_params: 14375
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 14
# list_number_filters: [12, 20, 35]
# before_prune_params: 14375
# new_model_params: 13933
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 15
# list_number_filters: [12, 17, 33]
# before_prune_params: 13933
# new_model_params: 12828
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 16
# list_number_filters: [12, 17, 30]
# before_prune_params: 12828
# new_model_params: 12165
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 17
# list_number_filters: [12, 16, 30]
# before_prune_params: 12165
# new_model_params: 11944
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 18
# list_number_filters: [11, 15, 29]
# before_prune_params: 11944
# new_model_params: 10540
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 19
# list_number_filters: [11, 14, 28]
# before_prune_params: 10540
# new_model_params: 10134
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 20
# list_number_filters: [10, 13, 26]
# before_prune_params: 10134
# new_model_params: 8657
# --- [INFO] This round PRUNE filter ---
# Val loss: 0.6871983408927917, Val accuracy: 0.5659180283546448
#
#  [INFO] Round 21
# list_number_filters: [10, 12, 24]
# before_prune_params: 8657
# new_model_params: 8102
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 22
# list_number_filters: [10, 12, 23]
# before_prune_params: 8102
# new_model_params: 7917
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 23
# list_number_filters: [9, 11, 22]
# before_prune_params: 7917
# new_model_params: 6791
# --- [INFO] This round PRUNE filter ---
#
#  [INFO] Round 24
# list_number_filters: [9, 11, 22]
# before_prune_params: 6791
# new_model_params: 6791
# --- [INFO] This round NOT prune filter ---
#
#  [INFO] Round 25
# list_number_filters: [9, 11, 22]
# before_prune_params: 6791
# new_model_params: 6791
# --- [INFO] This round NOT prune filter ---
#
#  [INFO] Round 26
# list_number_filters: [9, 11, 22]
# before_prune_params: 6791
# new_model_params: 6791
# --- [INFO] This round NOT prune filter ---
# ===== [INFO] Stop prune here! =====
# Final params: 6791
#
#  [INFO] Round 27
#
#  [INFO] Round 28
#
#  [INFO] Round 29
#
#  [INFO] Round 30
#
#  [INFO] Round 31
#
#  [INFO] Round 32
#
#  [INFO] Round 33
#
#  [INFO] Round 34
#
#  [INFO] Round 35
#
#  [INFO] Round 36
#
#  [INFO] Round 37
#
#  [INFO] Round 38
#
#  [INFO] Round 39
#
#  [INFO] Round 40
# Val loss: 0.7019661664962769, Val accuracy: 0.5065968632698059
#
#  [INFO] Round 41
#
#  [INFO] Round 42
#
#  [INFO] Round 43
#
#  [INFO] Round 44
#
#  [INFO] Round 45
#
#  [INFO] Round 46
#
#  [INFO] Round 47
#
#  [INFO] Round 48
#
#  [INFO] Round 49
#
#  [INFO] Round 50
#
#  [INFO] Round 51
#
#  [INFO] Round 52
#
#  [INFO] Round 53
#
#  [INFO] Round 54
#
#  [INFO] Round 55
#
#  [INFO] Round 56
#
#  [INFO] Round 57
#
#  [INFO] Round 58
#
#  [INFO] Round 59
#
#  [INFO] Round 60
# Val loss: 0.6510592103004456, Val accuracy: 0.6193976998329163
#
#  [INFO] Round 61
#
#  [INFO] Round 62
#
#  [INFO] Round 63
#
#  [INFO] Round 64
#
#  [INFO] Round 65
#
#  [INFO] Round 66
#
#  [INFO] Round 67
#
#  [INFO] Round 68
#
#  [INFO] Round 69
#
#  [INFO] Round 70
#
#  [INFO] Round 71
#
#  [INFO] Round 72
#
#  [INFO] Round 73
#
#  [INFO] Round 74
#
#  [INFO] Round 75
#
#  [INFO] Round 76
#
#  [INFO] Round 77
#
#  [INFO] Round 78
#
#  [INFO] Round 79
#
#  [INFO] Round 80
# Val loss: 0.5868945121765137, Val accuracy: 0.6977540254592896
#
#  [INFO] Round 81
#
#  [INFO] Round 82
#
#  [INFO] Round 83
#
#  [INFO] Round 84
#
#  [INFO] Round 85
#
#  [INFO] Round 86
#
#  [INFO] Round 87
#
#  [INFO] Round 88
#
#  [INFO] Round 89
#
#  [INFO] Round 90
#
#  [INFO] Round 91
#
#  [INFO] Round 92
#
#  [INFO] Round 93
#
#  [INFO] Round 94
#
#  [INFO] Round 95
#
#  [INFO] Round 96
#
#  [INFO] Round 97
#
#  [INFO] Round 98
#
#  [INFO] Round 99
#
#  [INFO] Round 100
# Val loss: 0.36055248975753784, Val accuracy: 0.8432873487472534
#
#  [INFO] Round 101
#
#  [INFO] Round 102
#
#  [INFO] Round 103
#
#  [INFO] Round 104
#
#  [INFO] Round 105
#
#  [INFO] Round 106
#
#  [INFO] Round 107
#
#  [INFO] Round 108
#
#  [INFO] Round 109
#
#  [INFO] Round 110
#
#  [INFO] Round 111
#
#  [INFO] Round 112
#
#  [INFO] Round 113
#
#  [INFO] Round 114
#
#  [INFO] Round 115
#
#  [INFO] Round 116
#
#  [INFO] Round 117
#
#  [INFO] Round 118
#
#  [INFO] Round 119
#
#  [INFO] Round 120
# Val loss: 0.32676902413368225, Val accuracy: 0.8610131740570068
#
#  [INFO] Round 121
#
#  [INFO] Round 122
#
#  [INFO] Round 123
#
#  [INFO] Round 124
#
#  [INFO] Round 125
#
#  [INFO] Round 126
#
#  [INFO] Round 127
#
#  [INFO] Round 128
#
#  [INFO] Round 129
#
#  [INFO] Round 130
#
#  [INFO] Round 131
#
#  [INFO] Round 132
#
#  [INFO] Round 133
#
#  [INFO] Round 134
#
#  [INFO] Round 135
#
#  [INFO] Round 136
#
#  [INFO] Round 137
#
#  [INFO] Round 138
#
#  [INFO] Round 139
#
#  [INFO] Round 140
# Val loss: 0.28400617837905884, Val accuracy: 0.8811562061309814
#
#  [INFO] Round 141
#
#  [INFO] Round 142
#
#  [INFO] Round 143
#
#  [INFO] Round 144
#
#  [INFO] Round 145
#
#  [INFO] Round 146
#
#  [INFO] Round 147
#
#  [INFO] Round 148
#
#  [INFO] Round 149
#
#  [INFO] Round 150
#
#  [INFO] Round 151
#
#  [INFO] Round 152
#
#  [INFO] Round 153
#
#  [INFO] Round 154
#
#  [INFO] Round 155
#
#  [INFO] Round 156
#
#  [INFO] Round 157
#
#  [INFO] Round 158
#
#  [INFO] Round 159
#
#  [INFO] Round 160
# Val loss: 0.26755595207214355, Val accuracy: 0.8877027034759521
#
#  [INFO] Round 161
#
#  [INFO] Round 162
#
#  [INFO] Round 163
#
#  [INFO] Round 164
#
#  [INFO] Round 165
#
#  [INFO] Round 166
#
#  [INFO] Round 167
#
#  [INFO] Round 168
#
#  [INFO] Round 169
#
#  [INFO] Round 170
#
#  [INFO] Round 171
#
#  [INFO] Round 172
#
#  [INFO] Round 173
#
#  [INFO] Round 174
#
#  [INFO] Round 175
#
#  [INFO] Round 176
#
#  [INFO] Round 177
#
#  [INFO] Round 178
#
#  [INFO] Round 179
#
#  [INFO] Round 180
# Val loss: 0.3152787387371063, Val accuracy: 0.8664517998695374
#
#  [INFO] Round 181
#
#  [INFO] Round 182
#
#  [INFO] Round 183
#
#  [INFO] Round 184
#
#  [INFO] Round 185
#
#  [INFO] Round 186
#
#  [INFO] Round 187
#
#  [INFO] Round 188
#
#  [INFO] Round 189
#
#  [INFO] Round 190
#
#  [INFO] Round 191
#
#  [INFO] Round 192
#
#  [INFO] Round 193
#
#  [INFO] Round 194
#
#  [INFO] Round 195
#
#  [INFO] Round 196
#
#  [INFO] Round 197
#
#  [INFO] Round 198
#
#  [INFO] Round 199
#
#  [INFO] Round 200
# Val loss: 0.2602308988571167, Val accuracy: 0.8920334577560425
#
#  [INFO] Round 201
#
#  [INFO] Round 202
#
#  [INFO] Round 203
#
#  [INFO] Round 204
#
#  [INFO] Round 205
#
#  [INFO] Round 206
#
#  [INFO] Round 207
#
#  [INFO] Round 208
#
#  [INFO] Round 209
#
#  [INFO] Round 210
#
#  [INFO] Round 211
#
#  [INFO] Round 212
#
#  [INFO] Round 213
#
#  [INFO] Round 214
#
#  [INFO] Round 215
#
#  [INFO] Round 216
#
#  [INFO] Round 217
#
#  [INFO] Round 218
#
#  [INFO] Round 219
#
#  [INFO] Round 220
# Val loss: 0.23381339013576508, Val accuracy: 0.9045221209526062
#
#  [INFO] Round 221
#
#  [INFO] Round 222
#
#  [INFO] Round 223
#
#  [INFO] Round 224
#
#  [INFO] Round 225
#
#  [INFO] Round 226
#
#  [INFO] Round 227
#
#  [INFO] Round 228
#
#  [INFO] Round 229
#
#  [INFO] Round 230
#
#  [INFO] Round 231
#
#  [INFO] Round 232
#
#  [INFO] Round 233
#
#  [INFO] Round 234
#
#  [INFO] Round 235
#
#  [INFO] Round 236
#
#  [INFO] Round 237
#
#  [INFO] Round 238
#
#  [INFO] Round 239
#
#  [INFO] Round 240
# Val loss: 0.23461388051509857, Val accuracy: 0.9030113816261292
#
#  [INFO] Round 241
#
#  [INFO] Round 242
#
#  [INFO] Round 243
#
#  [INFO] Round 244
#
#  [INFO] Round 245
#
#  [INFO] Round 246
#
#  [INFO] Round 247
#
#  [INFO] Round 248
#
#  [INFO] Round 249
#
#  [INFO] Round 250
#
#  [INFO] Round 251
#
#  [INFO] Round 252
#
#  [INFO] Round 253
#
#  [INFO] Round 254
#
#  [INFO] Round 255
#
#  [INFO] Round 256
#
#  [INFO] Round 257
#
#  [INFO] Round 258
#
#  [INFO] Round 259
#
#  [INFO] Round 260
# Val loss: 0.2477857619524002, Val accuracy: 0.8966663479804993
#
#  [INFO] Round 261
#
#  [INFO] Round 262
#
#  [INFO] Round 263
#
#  [INFO] Round 264
#
#  [INFO] Round 265
#
#  [INFO] Round 266
#
#  [INFO] Round 267
#
#  [INFO] Round 268
#
#  [INFO] Round 269
#
#  [INFO] Round 270
#
#  [INFO] Round 271
#
#  [INFO] Round 272
#
#  [INFO] Round 273
#
#  [INFO] Round 274
#
#  [INFO] Round 275
#
#  [INFO] Round 276
#
#  [INFO] Round 277
#
#  [INFO] Round 278
#
#  [INFO] Round 279
#
#  [INFO] Round 280
# Val loss: 0.23531849682331085, Val accuracy: 0.9033135175704956
#
#  [INFO] Round 281
#
#  [INFO] Round 282
#
#  [INFO] Round 283
#
#  [INFO] Round 284
#
#  [INFO] Round 285
#
#  [INFO] Round 286
#
#  [INFO] Round 287
#
#  [INFO] Round 288
#
#  [INFO] Round 289
#
#  [INFO] Round 290
#
#  [INFO] Round 291
#
#  [INFO] Round 292
#
#  [INFO] Round 293
#
#  [INFO] Round 294
#
#  [INFO] Round 295
#
#  [INFO] Round 296
#
#  [INFO] Round 297
#
#  [INFO] Round 298
#
#  [INFO] Round 299
#
#  [INFO] Round 300
# Val loss: 0.24579182267189026, Val accuracy: 0.8986806273460388
#
#  [INFO] Round 301
#
#  [INFO] Round 302
#
#  [INFO] Round 303
#
#  [INFO] Round 304
#
#  [INFO] Round 305
#
#  [INFO] Round 306
#
#  [INFO] Round 307
#
#  [INFO] Round 308
#
#  [INFO] Round 309
#
#  [INFO] Round 310
#
#  [INFO] Round 311
#
#  [INFO] Round 312
#
#  [INFO] Round 313
#
#  [INFO] Round 314
#
#  [INFO] Round 315
#
#  [INFO] Round 316
#
#  [INFO] Round 317
#
#  [INFO] Round 318
#
#  [INFO] Round 319
#
#  [INFO] Round 320
# Val loss: 0.22605662047863007, Val accuracy: 0.9082485437393188
#
#  [INFO] Round 321
#
#  [INFO] Round 322
#
#  [INFO] Round 323
#
#  [INFO] Round 324
#
#  [INFO] Round 325
#
#  [INFO] Round 326
#
#  [INFO] Round 327
#
#  [INFO] Round 328
#
#  [INFO] Round 329
#
#  [INFO] Round 330
#
#  [INFO] Round 331
#
#  [INFO] Round 332
#
#  [INFO] Round 333
#
#  [INFO] Round 334
#
#  [INFO] Round 335
#
#  [INFO] Round 336
#
#  [INFO] Round 337
#
#  [INFO] Round 338
#
#  [INFO] Round 339
#
#  [INFO] Round 340
# Val loss: 0.23523521423339844, Val accuracy: 0.9030113816261292
#
#  [INFO] Round 341
#
#  [INFO] Round 342
#
#  [INFO] Round 343
#
#  [INFO] Round 344
#
#  [INFO] Round 345
#
#  [INFO] Round 346
#
#  [INFO] Round 347
#
#  [INFO] Round 348
#
#  [INFO] Round 349
#
#  [INFO] Round 350
#
#  [INFO] Round 351
#
#  [INFO] Round 352
#
#  [INFO] Round 353
#
#  [INFO] Round 354
#
#  [INFO] Round 355
#
#  [INFO] Round 356
#
#  [INFO] Round 357
#
#  [INFO] Round 358
#
#  [INFO] Round 359
#
#  [INFO] Round 360
# Val loss: 0.234976664185524, Val accuracy: 0.9010977745056152
#
#  [INFO] Round 361
#
#  [INFO] Round 362
#
#  [INFO] Round 363
#
#  [INFO] Round 364
#
#  [INFO] Round 365
#
#  [INFO] Round 366
#
#  [INFO] Round 367
#
#  [INFO] Round 368
#
#  [INFO] Round 369
#
#  [INFO] Round 370
#
#  [INFO] Round 371
#
#  [INFO] Round 372
#
#  [INFO] Round 373
#
#  [INFO] Round 374
#
#  [INFO] Round 375
#
#  [INFO] Round 376
#
#  [INFO] Round 377
#
#  [INFO] Round 378
#
#  [INFO] Round 379
#
#  [INFO] Round 380
# Val loss: 0.2560008466243744, Val accuracy: 0.8954577445983887
#
#  [INFO] Round 381
#
#  [INFO] Round 382
#
#  [INFO] Round 383
#
#  [INFO] Round 384
#
#  [INFO] Round 385
#
#  [INFO] Round 386
#
#  [INFO] Round 387
#
#  [INFO] Round 388
#
#  [INFO] Round 389
#
#  [INFO] Round 390
#
#  [INFO] Round 391
#
#  [INFO] Round 392
#
#  [INFO] Round 393
#
#  [INFO] Round 394
#
#  [INFO] Round 395
#
#  [INFO] Round 396
#
#  [INFO] Round 397
#
#  [INFO] Round 398
#
#  [INFO] Round 399
#
#  [INFO] Round 400
# Val loss: 0.258412629365921, Val accuracy: 0.8922348618507385
#
#  [INFO] Round 401
#
#  [INFO] Round 402
#
#  [INFO] Round 403
#
#  [INFO] Round 404
#
#  [INFO] Round 405
#
#  [INFO] Round 406
#
#  [INFO] Round 407
#
#  [INFO] Round 408
#
#  [INFO] Round 409
#
#  [INFO] Round 410
#
#  [INFO] Round 411
#
#  [INFO] Round 412
#
#  [INFO] Round 413
#
#  [INFO] Round 414
#
#  [INFO] Round 415
#
#  [INFO] Round 416
#
#  [INFO] Round 417
#
#  [INFO] Round 418
#
#  [INFO] Round 419
#
#  [INFO] Round 420
# Val loss: 0.2682878375053406, Val accuracy: 0.8864941000938416
#
#  [INFO] Round 421
#
#  [INFO] Round 422
#
#  [INFO] Round 423
#
#  [INFO] Round 424
#
#  [INFO] Round 425
#
#  [INFO] Round 426
#
#  [INFO] Round 427
#
#  [INFO] Round 428
#
#  [INFO] Round 429
#
#  [INFO] Round 430
#
#  [INFO] Round 431
#
#  [INFO] Round 432
#
#  [INFO] Round 433
#
#  [INFO] Round 434
#
#  [INFO] Round 435
#
#  [INFO] Round 436
#
#  [INFO] Round 437
#
#  [INFO] Round 438
#
#  [INFO] Round 439
#
#  [INFO] Round 440
# Val loss: 0.2452254295349121, Val accuracy: 0.8983784914016724
#
#  [INFO] Round 441
#
#  [INFO] Round 442
#
#  [INFO] Round 443
#
#  [INFO] Round 444
#
#  [INFO] Round 445
#
#  [INFO] Round 446
#
#  [INFO] Round 447
#
#  [INFO] Round 448
#
#  [INFO] Round 449
#
#  [INFO] Round 450
#
#  [INFO] Round 451
#
#  [INFO] Round 452
#
#  [INFO] Round 453
#
#  [INFO] Round 454
#
#  [INFO] Round 455
#
#  [INFO] Round 456
#
#  [INFO] Round 457
#
#  [INFO] Round 458
#
#  [INFO] Round 459
#
#  [INFO] Round 460
# Val loss: 0.24517229199409485, Val accuracy: 0.8996877670288086
#
#  [INFO] Round 461
#
#  [INFO] Round 462
#
#  [INFO] Round 463
#
#  [INFO] Round 464
#
#  [INFO] Round 465
#
#  [INFO] Round 466
#
#  [INFO] Round 467
#
#  [INFO] Round 468
#
#  [INFO] Round 469
#
#  [INFO] Round 470
#
#  [INFO] Round 471
#
#  [INFO] Round 472
#
#  [INFO] Round 473
#
#  [INFO] Round 474
#
#  [INFO] Round 475
#
#  [INFO] Round 476
#
#  [INFO] Round 477
#
#  [INFO] Round 478
#
#  [INFO] Round 479
#
#  [INFO] Round 480
# Val loss: 0.25556397438049316, Val accuracy: 0.8953570127487183
#
#  [INFO] Round 481
#
#  [INFO] Round 482
#
#  [INFO] Round 483
#
#  [INFO] Round 484
#
#  [INFO] Round 485
#
#  [INFO] Round 486
#
#  [INFO] Round 487
#
#  [INFO] Round 488
#
#  [INFO] Round 489
#
#  [INFO] Round 490
#
#  [INFO] Round 491
#
#  [INFO] Round 492
#
#  [INFO] Round 493
#
#  [INFO] Round 494
#
#  [INFO] Round 495
#
#  [INFO] Round 496
#
#  [INFO] Round 497
#
#  [INFO] Round 498
#
#  [INFO] Round 499

# %%
# Line plot for FL training
list_rounds = np.arange(0, NUM_ROUNDS, 20)

plt.rcParams.update({'font.size': 14})

plt.plot(list_rounds, list_val_acc, '.-', label='val_acc')
plt.xlabel('Rounds')
plt.ylabel('Acc')

plt.legend()
plt.show()

# %% [markdown]
# # 3. Evaluation

# %%
# X_test = np.array([resize(image, (IMAGE_DIMENSION, IMAGE_DIMENSION)) for image in X_test])
print(f"Shape of X test: {X_test.shape}")
print(f"Shape of y test: {y_test.shape}")
# Out:
# Shape of X test: (9930, 84, 84, 3)
# Shape of y test: (9930, 2)

# %%
# Evaluate model on testing data
val_loss, val_acc = global_model.evaluate(X_test, y_test, verbose=0)
print(f'Val loss: {val_loss}, Val accuracy: {val_acc}')
# Out:
# Val loss: 0.34053948521614075, Val accuracy: 0.8583081364631653

# %%
print("=== AFTER PRUNING: ==")
print(f"Number of params: {global_model.count_params()}")
flops = get_flops_keras_model(global_model).as_integer_ratio()[0]
print(f"FLOPS of global model: {flops}")
# Out:
# === AFTER PRUNING: ==
# Number of params: 6791
# FLOPS of global model: 1610012
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   1.57m float_ops (100.00%, 97.55%)
# BiasAdd                  20.83k float_ops (2.45%, 1.29%)
# MaxPool                  15.88k float_ops (1.15%, 0.99%)
# AddV2                    1.41k float_ops (0.17%, 0.09%)
# MatMul                   1.30k float_ops (0.08%, 0.08%)
# Softmax                     10 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
