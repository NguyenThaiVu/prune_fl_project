# %% [markdown]
# # Description
#
# In this notebook, I will train the Federated Learning system with **ResNet architecture.**

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
tf.random.set_seed(42)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:  tf.config.experimental.set_memory_growth(gpus[0], True)
  except RuntimeError as e: print(e)

import gc
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skimage.transform import resize

from sklearn.model_selection import train_test_split

from config_celeb import *
from utils.read_data_utils import *
from utils.model_utils import *
from utils.pruning_utils import *
# Out:
# 2024-06-07 12:53:48.068968: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 12:53:48.068987: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 12:53:48.069000: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import os

# =========================================================
# Dataset Hyper-parameter
DATASET_NAME = 'celeb'  # mnist or celeb

IMAGE_DIMENSION = 84
INPUT_SHAPE = (IMAGE_DIMENSION, IMAGE_DIMENSION, 3)
OUPUT_SHAPE = 2
LABEL_NAME = {0: 'female', 1: 'male'}    # Gender classification 


# =========================================================
# Model Hyper-parameter
OPTIMIZER = 'adam'
LOSS = 'categorical_crossentropy'
METRICS = ['accuracy']

MODEL_TYPE = "vanilla_conv" # ['vanilla_conv', 'resnet', 'xception']

LIST_NUMBER_FILTERS = [16, 32, 64]  # for 'vanilla_conv'
KERNEL_SIZE = 5
DROPOUT_RATE = 0.1
PATH_GLOBAL_MODEL = os.path.join("models", "global_model_resnet_celeb.h5")


# =========================================================
# Training Hyper-parameter
NUM_ROUNDS = 500
NUM_SELECTED_CLIENT = 50

LOCAL_EPOCHS = 5
LOCAL_BATCH_SIZE = 32

# %% [markdown]
# # 1. Dataset

# %% [markdown]
# ## 1.1. Load dataset

# %%
celeb_train, celeb_test = tff.simulation.datasets.celeba.load_data()

num_clients = len(celeb_train.client_ids)
print(f"Number of clients: {num_clients}")
# Out:
# Number of clients: 8408

# %% [markdown]
# ## 1.2. Prepare training dataset

# %%
list_clients_data = Create_Clients_Data(celeb_train, DATASET_NAME)
print(f"Number of client: {len(list_clients_data)}")
# Out:
# Number of client: 8408

# %%
idx_client = np.random.randint(0, 10)
idx_sample = np.random.randint(0, 10)

client_data = list_clients_data[idx_client]

client_name = client_data['client_name']
list_X = client_data['list_X']
list_y = client_data['list_y']

X = list_X[idx_sample]
print(f"Shape of image: {X.shape}")
print(f"Max value of X: {X.max()}")
print(f"Min value of X: {X.min()}")

y = list_y[idx_sample]

print(f"Client = {client_name}")
print(f"Label = {y}")
plt.imshow(X, cmap='gray')
plt.show()
# Out:
# Shape of image: (84, 84, 3)
# Max value of X: 255
# Min value of X: 1
# Client = 10006
# Label = [0. 1.]

# %% [markdown]
# ## 1.3. Prepare val - test dataset

# %%
list_data_test = Create_Clients_Data(celeb_test, dataset_name=DATASET_NAME)

X_test = []
y_test = []
for data_test in list_data_test:
    X_test.append(data_test['list_X'])
    y_test.append(data_test['list_y'])
X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=42)
X_val = np.array([resize(image, (IMAGE_DIMENSION, IMAGE_DIMENSION)) for image in X_val])
X_test = np.array([resize(image, (IMAGE_DIMENSION, IMAGE_DIMENSION)) for image in X_test])

# %%
print(f"Shape of X val: {X_val.shape}")
print(f"Shape of y val: {y_val.shape}")
print(f"Max value of X_val: {X_val[3].max()}")
print(f"Min value of X_val: {X_val[3].min()}")
print()
print(f"Shape of X test: {X_test.shape}")
print(f"Shape of y test: {y_test.shape}")
# Out:
# Shape of X val: (9929, 84, 84, 3)
# Shape of y val: (9929, 2)
# Max value of X_val: 1.0
# Min value of X_val: 0.0
#
# Shape of X test: (9930, 84, 84, 3)
# Shape of y test: (9930, 2)

# %% [markdown]
# # 2. FL Training
#
# ## 2.1. Define components

# %%
def Define_ResNet_Model(input_shape, output_shape, list_number_filters, max_pooling_step=2, model_name=None):
    """
    This function create the simple Residual Network model. 
    """
    inputs = layers.Input(shape=input_shape)
    
    # Initial Convolutional Layer
    x = layers.Conv2D(list_number_filters[0], kernel_size=3, strides=2, padding='same', name=f'prunable_conv_0')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(pool_size=max_pooling_step, strides=max_pooling_step, padding='same')(x)
    
    # Residual Blocks
    for (idx_residual_block, number_filters) in enumerate(list_number_filters[1:]):
        x = residual_block(x, num_filters_1=number_filters, num_filters_2=number_filters, strides=(2, 2), idx_residual_block=idx_residual_block)
    
    # Final Layers
    # x = layers.GlobalAveragePooling2D()(x)
    x = Flatten()(x)
    x = layers.Dense(output_shape, activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=x)
    return model

# %%
keras.backend.clear_session()
global_model = Define_ResNet_Model(INPUT_SHAPE, OUPUT_SHAPE, LIST_NUMBER_FILTERS, max_pooling_step=2, model_name=None)
global_model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics = METRICS)
print(f"Number of params: {global_model.count_params()}")

num_conv_layers = Count_Conv2d_Layers(global_model)
print(f"Number of Conv2D layer: {num_conv_layers}")
plot_model(global_model, to_file=os.path.join('images', f'ResNet-{num_conv_layers}.png'), show_shapes=True, show_layer_names=True);
global_model.save(PATH_GLOBAL_MODEL)
# Out:
# Number of params: 30626
# Number of Conv2D layer: 7
# /home/necphy/miniconda3/envs/fl_env/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## 2.2. FL training

# %%
NUM_CLIENTS = num_clients
list_val_acc = []
list_val_loss = []
list_model_params = []


for idx_round in range(NUM_ROUNDS):
    print("\n [INFO] Round {}".format(idx_round))
    global_model = tf.keras.models.load_model(PATH_GLOBAL_MODEL)
    global_model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics = METRICS)
    
    client_model = keras.models.clone_model(global_model)    
    client_model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics=METRICS)
    
    selected_clients_data = random.sample(list_clients_data, NUM_SELECTED_CLIENT)

    # Loop through selected client
    list_client_model_weight = []
    list_client_scales = []
    for selectd_client_data in selected_clients_data:      

        # Clone client's weight from global model
        client_model.set_weights(global_model.get_weights())

        client_name = selectd_client_data['client_name']
        list_X = selectd_client_data['list_X']
        list_y = selectd_client_data['list_y']
        list_X = list_X.astype(np.float32) / 255.0

        client_model.fit(list_X, list_y, epochs=LOCAL_EPOCHS, batch_size=LOCAL_BATCH_SIZE, verbose=0)

        list_client_model_weight.append(client_model.get_weights())    # store local weight for update global model later.
        list_client_scales.append(len(list_X))

    
    # Calculate scale of each client
    list_client_scales = np.array(list_client_scales)
    list_client_scales = list_client_scales / list_client_scales.sum()

    # Update the global model weights
    avg_weights = FedAvg(global_model, list_client_model_weight, list_client_scales)
    global_model.set_weights(avg_weights)

    # Evaluate model on validation data
    if idx_round % 20 == 0:
        val_loss, val_acc = global_model.evaluate(X_val, y_val, verbose=0)
        print(f'Val loss: {val_loss}, Val accuracy: {val_acc}')
        list_val_acc.append(val_acc)
        list_val_loss.append(val_loss)

    global_model.save(PATH_GLOBAL_MODEL)
    selected_clients_data = None
    list_client_model_weight = list_client_scales = None
    tf.keras.backend.clear_session()
    gc.collect()
# Out:
#  [INFO] Round 0
# Val loss: 0.6800198554992676, Val accuracy: 0.5889817476272583
#
#  [INFO] Round 1
#
#  [INFO] Round 2
#
#  [INFO] Round 3
#
#  [INFO] Round 4
#
#  [INFO] Round 5
#
#  [INFO] Round 6
#
#  [INFO] Round 7
#
#  [INFO] Round 8
#
#  [INFO] Round 9
#
#  [INFO] Round 10
#
#  [INFO] Round 11
#
#  [INFO] Round 12
#
#  [INFO] Round 13
#
#  [INFO] Round 14
#
#  [INFO] Round 15
#
#  [INFO] Round 16
#
#  [INFO] Round 17
#
#  [INFO] Round 18
#
#  [INFO] Round 19
#
#  [INFO] Round 20
# Val loss: 0.6472188830375671, Val accuracy: 0.6584751605987549
#
#  [INFO] Round 21
#
#  [INFO] Round 22
#
#  [INFO] Round 23
#
#  [INFO] Round 24
#
#  [INFO] Round 25
#
#  [INFO] Round 26
#
#  [INFO] Round 27
#
#  [INFO] Round 28
#
#  [INFO] Round 29
#
#  [INFO] Round 30
#
#  [INFO] Round 31
#
#  [INFO] Round 32
#
#  [INFO] Round 33
#
#  [INFO] Round 34
#
#  [INFO] Round 35
#
#  [INFO] Round 36
#
#  [INFO] Round 37
#
#  [INFO] Round 38
#
#  [INFO] Round 39
#
#  [INFO] Round 40
# Val loss: 0.5300248861312866, Val accuracy: 0.7565716505050659
#
#  [INFO] Round 41
#
#  [INFO] Round 42
#
#  [INFO] Round 43
#
#  [INFO] Round 44
#
#  [INFO] Round 45
#
#  [INFO] Round 46
#
#  [INFO] Round 47
#
#  [INFO] Round 48
#
#  [INFO] Round 49
#
#  [INFO] Round 50
#
#  [INFO] Round 51
#
#  [INFO] Round 52
#
#  [INFO] Round 53
#
#  [INFO] Round 54
#
#  [INFO] Round 55
#
#  [INFO] Round 56
#
#  [INFO] Round 57
#
#  [INFO] Round 58
#
#  [INFO] Round 59
#
#  [INFO] Round 60
# Val loss: 0.3552515208721161, Val accuracy: 0.8503373861312866
#
#  [INFO] Round 61
#
#  [INFO] Round 62
#
#  [INFO] Round 63
#
#  [INFO] Round 64
#
#  [INFO] Round 65
#
#  [INFO] Round 66
#
#  [INFO] Round 67
#
#  [INFO] Round 68
#
#  [INFO] Round 69
#
#  [INFO] Round 70
#
#  [INFO] Round 71
#
#  [INFO] Round 72
#
#  [INFO] Round 73
#
#  [INFO] Round 74
#
#  [INFO] Round 75
#
#  [INFO] Round 76
#
#  [INFO] Round 77
#
#  [INFO] Round 78
#
#  [INFO] Round 79
#
#  [INFO] Round 80
# Val loss: 0.23634923994541168, Val accuracy: 0.9022056460380554
#
#  [INFO] Round 81
#
#  [INFO] Round 82
#
#  [INFO] Round 83
#
#  [INFO] Round 84
#
#  [INFO] Round 85
#
#  [INFO] Round 86
#
#  [INFO] Round 87
#
#  [INFO] Round 88
#
#  [INFO] Round 89
#
#  [INFO] Round 90
#
#  [INFO] Round 91
#
#  [INFO] Round 92
#
#  [INFO] Round 93
#
#  [INFO] Round 94
#
#  [INFO] Round 95
#
#  [INFO] Round 96
#
#  [INFO] Round 97
#
#  [INFO] Round 98
#
#  [INFO] Round 99
#
#  [INFO] Round 100
# Val loss: 0.21933431923389435, Val accuracy: 0.9139893054962158
#
#  [INFO] Round 101
#
#  [INFO] Round 102
#
#  [INFO] Round 103
#
#  [INFO] Round 104
#
#  [INFO] Round 105
#
#  [INFO] Round 106
#
#  [INFO] Round 107
#
#  [INFO] Round 108
#
#  [INFO] Round 109
#
#  [INFO] Round 110
#
#  [INFO] Round 111
#
#  [INFO] Round 112
#
#  [INFO] Round 113
#
#  [INFO] Round 114
#
#  [INFO] Round 115
#
#  [INFO] Round 116
#
#  [INFO] Round 117
#
#  [INFO] Round 118
#
#  [INFO] Round 119
#
#  [INFO] Round 120
# Val loss: 0.19446641206741333, Val accuracy: 0.9220465421676636
#
#  [INFO] Round 121
#
#  [INFO] Round 122
#
#  [INFO] Round 123
#
#  [INFO] Round 124
#
#  [INFO] Round 125
#
#  [INFO] Round 126
#
#  [INFO] Round 127
#
#  [INFO] Round 128
#
#  [INFO] Round 129
#
#  [INFO] Round 130
#
#  [INFO] Round 131
#
#  [INFO] Round 132
#
#  [INFO] Round 133
#
#  [INFO] Round 134
#
#  [INFO] Round 135
#
#  [INFO] Round 136
#
#  [INFO] Round 137
#
#  [INFO] Round 138
#
#  [INFO] Round 139
#
#  [INFO] Round 140
# Val loss: 0.31353116035461426, Val accuracy: 0.8880048394203186
#
#  [INFO] Round 141
#
#  [INFO] Round 142
#
#  [INFO] Round 143
#
#  [INFO] Round 144
#
#  [INFO] Round 145
#
#  [INFO] Round 146
#
#  [INFO] Round 147
#
#  [INFO] Round 148
#
#  [INFO] Round 149
#
#  [INFO] Round 150
#
#  [INFO] Round 151
#
#  [INFO] Round 152
#
#  [INFO] Round 153
#
#  [INFO] Round 154
#
#  [INFO] Round 155
#
#  [INFO] Round 156
#
#  [INFO] Round 157
#
#  [INFO] Round 158
#
#  [INFO] Round 159
#
#  [INFO] Round 160
# Val loss: 0.1987658143043518, Val accuracy: 0.9227515459060669
#
#  [INFO] Round 161
#
#  [INFO] Round 162
#
#  [INFO] Round 163
#
#  [INFO] Round 164
#
#  [INFO] Round 165
#
#  [INFO] Round 166
#
#  [INFO] Round 167
#
#  [INFO] Round 168
#
#  [INFO] Round 169
#
#  [INFO] Round 170
#
#  [INFO] Round 171
#
#  [INFO] Round 172
#
#  [INFO] Round 173
#
#  [INFO] Round 174
#
#  [INFO] Round 175
#
#  [INFO] Round 176
#
#  [INFO] Round 177
#
#  [INFO] Round 178
#
#  [INFO] Round 179
#
#  [INFO] Round 180
# Val loss: 0.2274262011051178, Val accuracy: 0.9123778939247131
#
#  [INFO] Round 181
#
#  [INFO] Round 182
#
#  [INFO] Round 183
#
#  [INFO] Round 184
#
#  [INFO] Round 185
#
#  [INFO] Round 186
#
#  [INFO] Round 187
#
#  [INFO] Round 188
#
#  [INFO] Round 189
#
#  [INFO] Round 190
#
#  [INFO] Round 191
#
#  [INFO] Round 192
#
#  [INFO] Round 193
#
#  [INFO] Round 194
#
#  [INFO] Round 195
#
#  [INFO] Round 196
#
#  [INFO] Round 197
#
#  [INFO] Round 198
#
#  [INFO] Round 199
#
#  [INFO] Round 200
# Val loss: 0.2533250153064728, Val accuracy: 0.9038171172142029
#
#  [INFO] Round 201
#
#  [INFO] Round 202
#
#  [INFO] Round 203
#
#  [INFO] Round 204
#
#  [INFO] Round 205
#
#  [INFO] Round 206
#
#  [INFO] Round 207
#
#  [INFO] Round 208
#
#  [INFO] Round 209
#
#  [INFO] Round 210
#
#  [INFO] Round 211
#
#  [INFO] Round 212
#
#  [INFO] Round 213
#
#  [INFO] Round 214
#
#  [INFO] Round 215
#
#  [INFO] Round 216
#
#  [INFO] Round 217
#
#  [INFO] Round 218
#
#  [INFO] Round 219
#
#  [INFO] Round 220
# Val loss: 0.1977974772453308, Val accuracy: 0.9224494099617004
#
#  [INFO] Round 221
#
#  [INFO] Round 222
#
#  [INFO] Round 223
#
#  [INFO] Round 224
#
#  [INFO] Round 225
#
#  [INFO] Round 226
#
#  [INFO] Round 227
#
#  [INFO] Round 228
#
#  [INFO] Round 229
#
#  [INFO] Round 230
#
#  [INFO] Round 231
#
#  [INFO] Round 232
#
#  [INFO] Round 233
#
#  [INFO] Round 234
#
#  [INFO] Round 235
#
#  [INFO] Round 236
#
#  [INFO] Round 237
#
#  [INFO] Round 238
#
#  [INFO] Round 239
#
#  [INFO] Round 240
# Val loss: 0.19771358370780945, Val accuracy: 0.9224494099617004
#
#  [INFO] Round 241
#
#  [INFO] Round 242
#
#  [INFO] Round 243
#
#  [INFO] Round 244
#
#  [INFO] Round 245
#
#  [INFO] Round 246
#
#  [INFO] Round 247
#
#  [INFO] Round 248
#
#  [INFO] Round 249
#
#  [INFO] Round 250
#
#  [INFO] Round 251
#
#  [INFO] Round 252
#
#  [INFO] Round 253
#
#  [INFO] Round 254
#
#  [INFO] Round 255
#
#  [INFO] Round 256
#
#  [INFO] Round 257
#
#  [INFO] Round 258
#
#  [INFO] Round 259
#
#  [INFO] Round 260
# Val loss: 0.18620073795318604, Val accuracy: 0.929600179195404
#
#  [INFO] Round 261
#
#  [INFO] Round 262
#
#  [INFO] Round 263
#
#  [INFO] Round 264
#
#  [INFO] Round 265
#
#  [INFO] Round 266
#
#  [INFO] Round 267
#
#  [INFO] Round 268
#
#  [INFO] Round 269
#
#  [INFO] Round 270
#
#  [INFO] Round 271
#
#  [INFO] Round 272
#
#  [INFO] Round 273
#
#  [INFO] Round 274
#
#  [INFO] Round 275
#
#  [INFO] Round 276
#
#  [INFO] Round 277
#
#  [INFO] Round 278
#
#  [INFO] Round 279
#
#  [INFO] Round 280
# Val loss: 0.19230835139751434, Val accuracy: 0.925974428653717
#
#  [INFO] Round 281
#
#  [INFO] Round 282
#
#  [INFO] Round 283
#
#  [INFO] Round 284
#
#  [INFO] Round 285
#
#  [INFO] Round 286
#
#  [INFO] Round 287
#
#  [INFO] Round 288
#
#  [INFO] Round 289
#
#  [INFO] Round 290
#
#  [INFO] Round 291
#
#  [INFO] Round 292
#
#  [INFO] Round 293
#
#  [INFO] Round 294
#
#  [INFO] Round 295
#
#  [INFO] Round 296
#
#  [INFO] Round 297
#
#  [INFO] Round 298
#
#  [INFO] Round 299
#
#  [INFO] Round 300
# Val loss: 0.27519211173057556, Val accuracy: 0.8941484689712524
#
#  [INFO] Round 301
#
#  [INFO] Round 302
#
#  [INFO] Round 303
#
#  [INFO] Round 304
#
#  [INFO] Round 305
#
#  [INFO] Round 306
#
#  [INFO] Round 307
#
#  [INFO] Round 308
#
#  [INFO] Round 309
#
#  [INFO] Round 310
#
#  [INFO] Round 311
#
#  [INFO] Round 312
#
#  [INFO] Round 313
#
#  [INFO] Round 314
#
#  [INFO] Round 315
#
#  [INFO] Round 316
#
#  [INFO] Round 317
#
#  [INFO] Round 318
#
#  [INFO] Round 319
#
#  [INFO] Round 320
# Val loss: 0.262738972902298, Val accuracy: 0.8985798954963684
#
#  [INFO] Round 321
#
#  [INFO] Round 322
#
#  [INFO] Round 323
#
#  [INFO] Round 324
#
#  [INFO] Round 325
#
#  [INFO] Round 326
#
#  [INFO] Round 327
#
#  [INFO] Round 328
#
#  [INFO] Round 329
#
#  [INFO] Round 330
#
#  [INFO] Round 331
#
#  [INFO] Round 332
#
#  [INFO] Round 333
#
#  [INFO] Round 334
#
#  [INFO] Round 335
#
#  [INFO] Round 336
#
#  [INFO] Round 337
#
#  [INFO] Round 338
#
#  [INFO] Round 339
#
#  [INFO] Round 340
# Val loss: 0.22241343557834625, Val accuracy: 0.911270022392273
#
#  [INFO] Round 341
#
#  [INFO] Round 342
#
#  [INFO] Round 343
#
#  [INFO] Round 344
#
#  [INFO] Round 345
#
#  [INFO] Round 346
#
#  [INFO] Round 347
#
#  [INFO] Round 348
#
#  [INFO] Round 349
#
#  [INFO] Round 350
#
#  [INFO] Round 351
#
#  [INFO] Round 352
#
#  [INFO] Round 353
#
#  [INFO] Round 354
#
#  [INFO] Round 355
#
#  [INFO] Round 356
#
#  [INFO] Round 357
#
#  [INFO] Round 358
#
#  [INFO] Round 359
#
#  [INFO] Round 360
# Val loss: 0.20671406388282776, Val accuracy: 0.9176150560379028
#
#  [INFO] Round 361
#
#  [INFO] Round 362
#
#  [INFO] Round 363
#
#  [INFO] Round 364
#
#  [INFO] Round 365
#
#  [INFO] Round 366
#
#  [INFO] Round 367
#
#  [INFO] Round 368
#
#  [INFO] Round 369
#
#  [INFO] Round 370
#
#  [INFO] Round 371
#
#  [INFO] Round 372
#
#  [INFO] Round 373
#
#  [INFO] Round 374
#
#  [INFO] Round 375
#
#  [INFO] Round 376
#
#  [INFO] Round 377
#
#  [INFO] Round 378
#
#  [INFO] Round 379
#
#  [INFO] Round 380
# Val loss: 0.19021287560462952, Val accuracy: 0.925974428653717
#
#  [INFO] Round 381
#
#  [INFO] Round 382
#
#  [INFO] Round 383
#
#  [INFO] Round 384
#
#  [INFO] Round 385
#
#  [INFO] Round 386
#
#  [INFO] Round 387
#
#  [INFO] Round 388
#
#  [INFO] Round 389
#
#  [INFO] Round 390
#
#  [INFO] Round 391
#
#  [INFO] Round 392
#
#  [INFO] Round 393
#
#  [INFO] Round 394
#
#  [INFO] Round 395
#
#  [INFO] Round 396
#
#  [INFO] Round 397
#
#  [INFO] Round 398
#
#  [INFO] Round 399
#
#  [INFO] Round 400
# Val loss: 0.2129470854997635, Val accuracy: 0.9139893054962158
#
#  [INFO] Round 401
#
#  [INFO] Round 402
#
#  [INFO] Round 403
#
#  [INFO] Round 404
#
#  [INFO] Round 405
#
#  [INFO] Round 406
#
#  [INFO] Round 407
#
#  [INFO] Round 408
#
#  [INFO] Round 409
#
#  [INFO] Round 410
#
#  [INFO] Round 411
#
#  [INFO] Round 412
#
#  [INFO] Round 413
#
#  [INFO] Round 414
#
#  [INFO] Round 415
#
#  [INFO] Round 416
#
#  [INFO] Round 417
#
#  [INFO] Round 418
#
#  [INFO] Round 419
#
#  [INFO] Round 420
# Val loss: 0.20064081251621246, Val accuracy: 0.9192265272140503
#
#  [INFO] Round 421
#
#  [INFO] Round 422
#
#  [INFO] Round 423
#
#  [INFO] Round 424
#
#  [INFO] Round 425
#
#  [INFO] Round 426
#
#  [INFO] Round 427
#
#  [INFO] Round 428
#
#  [INFO] Round 429
#
#  [INFO] Round 430
#
#  [INFO] Round 431
#
#  [INFO] Round 432
#
#  [INFO] Round 433
#
#  [INFO] Round 434
#
#  [INFO] Round 435
#
#  [INFO] Round 436
#
#  [INFO] Round 437
#
#  [INFO] Round 438
#
#  [INFO] Round 439
#
#  [INFO] Round 440
# Val loss: 0.24458454549312592, Val accuracy: 0.9005942344665527
#
#  [INFO] Round 441
#
#  [INFO] Round 442
#
#  [INFO] Round 443
#
#  [INFO] Round 444
#
#  [INFO] Round 445
#
#  [INFO] Round 446
#
#  [INFO] Round 447
#
#  [INFO] Round 448
#
#  [INFO] Round 449
#
#  [INFO] Round 450
#
#  [INFO] Round 451
#
#  [INFO] Round 452
#
#  [INFO] Round 453
#
#  [INFO] Round 454
#
#  [INFO] Round 455
#
#  [INFO] Round 456
#
#  [INFO] Round 457
#
#  [INFO] Round 458
#
#  [INFO] Round 459
#
#  [INFO] Round 460
# Val loss: 0.3249723017215729, Val accuracy: 0.8742068409919739
#
#  [INFO] Round 461
#
#  [INFO] Round 462
#
#  [INFO] Round 463
#
#  [INFO] Round 464
#
#  [INFO] Round 465
#
#  [INFO] Round 466
#
#  [INFO] Round 467
#
#  [INFO] Round 468
#
#  [INFO] Round 469
#
#  [INFO] Round 470
#
#  [INFO] Round 471
#
#  [INFO] Round 472
#
#  [INFO] Round 473
#
#  [INFO] Round 474
#
#  [INFO] Round 475
#
#  [INFO] Round 476
#
#  [INFO] Round 477
#
#  [INFO] Round 478
#
#  [INFO] Round 479
#
#  [INFO] Round 480
# Val loss: 0.25921911001205444, Val accuracy: 0.8937456011772156
#
#  [INFO] Round 481
#
#  [INFO] Round 482
#
#  [INFO] Round 483
#
#  [INFO] Round 484
#
#  [INFO] Round 485
#
#  [INFO] Round 486
#
#  [INFO] Round 487
#
#  [INFO] Round 488
#
#  [INFO] Round 489
#
#  [INFO] Round 490
#
#  [INFO] Round 491
#
#  [INFO] Round 492
#
#  [INFO] Round 493
#
#  [INFO] Round 494
#
#  [INFO] Round 495
#
#  [INFO] Round 496
#
#  [INFO] Round 497
#
#  [INFO] Round 498
#
#  [INFO] Round 499

# %% [markdown]
# # 3. Evaluation

# %%
# X_test = np.array([resize(image, (IMAGE_DIMENSION, IMAGE_DIMENSION)) for image in X_test])
print(f"Shape of X test: {X_test.shape}")
print(f"Shape of y test: {y_test.shape}")
# Out:
# Shape of X test: (9930, 84, 84, 3)
# Shape of y test: (9930, 2)

# %%
# Evaluate model on testing data
val_loss, val_acc = global_model.evaluate(X_test, y_test, verbose=0)
print(f'Val loss: {val_loss}, Val accuracy: {val_acc}')
# Out:
# Val loss: 0.2650549113750458, Val accuracy: 0.8950654864311218
